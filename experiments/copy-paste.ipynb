# %% [markdown]
# # Copy-paste detection experiments

# %% [markdown]
# ### Required imports

# %%
import os
import sys

PROJECT_ROOT = os.path.abspath(os.path.join(os.getcwd(), ".."))
if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)

from main.patchmatch import PatchMatch
from main.detector import CopyPasteDetector as CPD
from utils.helpers import detection_results, display_results

# %% [markdown]
# ## First experiment

# %%
img_path = "../images/fleur_copy_paste_normal.png"
patch_size = 7
iterations = 5
min_norm = 15
diff_threshold = 500.0

detector = CPD(img_path, patch_size, iterations, min_norm, diff_threshold)
mask = detector.detect_copy_paste()
result = detection_results(img_path, mask)
display_results(img_path, result, diff_threshold)
# Out:
# Forward pass 1...: 100%|██████████| 562/562 [00:01<00:00, 328.59it/s]
# Forward pass 1...: 100%|██████████| 562/562 [00:01<00:00, 328.59it/s]
# Reverse pass 1...: 100%|██████████| 562/562 [00:01<00:00, 332.44it/s]
# Reverse pass 1...: 100%|██████████| 562/562 [00:01<00:00, 332.44it/s]
# Forward pass 2...: 100%|██████████| 562/562 [00:01<00:00, 327.81it/s]
# Forward pass 2...: 100%|██████████| 562/562 [00:01<00:00, 327.81it/s]
# Reverse pass 2...: 100%|██████████| 562/562 [00:01<00:00, 316.09it/s]
# Reverse pass 2...: 100%|██████████| 562/562 [00:01<00:00, 316.09it/s]
# Forward pass 3...: 100%|██████████| 562/562 [00:01<00:00, 330.74it/s]
# Forward pass 3...: 100%|██████████| 562/562 [00:01<00:00, 330.74it/s]
# Reverse pass 3...: 100%|██████████| 562/562 [00:01<00:00, 326.54it/s]
# Reverse pass 3...: 100%|██████████| 562/562 [00:01<00:00, 326.54it/s]
# Forward pass 4...: 100%|██████████| 562/562 [00:01<00:00, 330.86it/s]
# Forward pass 4...: 100%|██████████| 562/562 [00:01<00:00, 330.86it/s]
# Reverse pass 4...: 100%|██████████| 562/562 [00:01<00:00, 330.05it/s]
# Reverse pass 4...: 100%|██████████| 562/562 [00:01<00:00, 330.05it/s]
# Forward pass 5...: 100%|██████████| 562/562 [00:01<00:00, 330.32it/s]
# Forward pass 5...: 100%|██████████| 562/562 [00:01<00:00, 330.32it/s]
# Reverse pass 5...: 100%|██████████| 562/562 [00:01<00:00, 329.48it/s]
# Total time to run patch match: 17.1458 seconds

# %% [markdown]
# ## Second experiment
