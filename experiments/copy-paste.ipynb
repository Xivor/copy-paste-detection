# %% [markdown]
# # Copy-paste detection experiments

# %% [markdown]
# ### Required imports

# %%
import os
import sys

PROJECT_ROOT = os.path.abspath(os.path.join(os.getcwd(), ".."))
if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)

import skimage.io
from main.patchmatch import PatchMatch
from main.detector import CopyPasteDetector as CPD
from utils.helpers import detection_results, display_results

# %% [markdown]
# ## First experiment

# %% [markdown]
# #### Defining PatchMatch parameteres and running algorithm

# %%
img_path = "../images/fleur_copy_paste_normal.png"
img = skimage.io.imread(img_path)
patch_size = 7
iterations = 5
min_norm = 15
diff_threshold = 500.0

detector = CPD(img, patch_size, iterations, min_norm, diff_threshold)
img = detector.img

# %% [markdown]
# ### Defining pairing parameters

# %%
cluster_eps=2.0
flat_threshold=0.05
min_cluster_size=300

# %% [markdown]
# ### Running copy-paste pairs detection

# %%
paired_result = detector.detect_paired_regions(cluster_eps, flat_threshold, min_cluster_size)
result = detection_results(img, paired_result)
display_results(img, result)

# %% [markdown]
# ## Second experiment

# %% [markdown]
# #### Defining PatchMatch parameteres and running algorithm

# %%
img_path = "../images/suburb_copy_paste_normal.png"
img = skimage.io.imread(img_path)
patch_size = 7
iterations = 5
min_norm = 15
diff_threshold = 500.0

detector = CPD(img, patch_size, iterations, min_norm, diff_threshold)
img = detector.img

# %% [markdown]
# ### Defining pairing parameters

# %%
cluster_eps=2.0
flat_threshold=0.05
min_cluster_size=300

# %% [markdown]
# ### Running copy-paste pairs detection

# %%
paired_result = detector.detect_paired_regions(cluster_eps, flat_threshold, min_cluster_size)
result = detection_results(img, paired_result)
display_results(img, result)

# %% [markdown]
# ## Third experiment

# %% [markdown]
# #### Defining PatchMatch parameteres and running algorithm

# %%
img_path = "../images/cercles_copy_paste_normal.png"
img = skimage.io.imread(img_path)
patch_size = 7
iterations = 5
min_norm = 15
diff_threshold = 500.0

detector = CPD(img, patch_size, iterations, min_norm, diff_threshold)
img = detector.img

# %% [markdown]
# ### Defining pairing parameters

# %%
cluster_eps=2.0
flat_threshold=0.05
min_cluster_size=300

# %% [markdown]
# ### Running copy-paste pairs detection

# %%
paired_result = detector.detect_paired_regions(cluster_eps, flat_threshold, min_cluster_size)
result = detection_results(img, paired_result)
display_results(img, result)

# %% [markdown]
# ## Fourth experiment

# %% [markdown]
# #### Defining PatchMatch parameteres and running algorithm

# %%
img_path = "../images/fleur_copy_paste_gauss.png"
img = skimage.io.imread(img_path)
patch_size = 7
iterations = 5
min_norm = 15
diff_threshold = 500.0

detector = CPD(img, patch_size, iterations, min_norm, diff_threshold, gaussian_filtering=True)
img = detector.img

# %% [markdown]
# ### Defining pairing parameters

# %%
cluster_eps=2.0
flat_threshold=0.05
min_cluster_size=300

# %% [markdown]
# ### Running copy-paste pairs detection

# %%
paired_result = detector.detect_paired_regions(cluster_eps, flat_threshold, min_cluster_size)
result = detection_results(img, paired_result)
display_results(img, result)

# %% [markdown]
# ## Fifth experiment

# %% [markdown]
# #### Defining PatchMatch parameteres and running algorithm

# %%
img_path = "../images/suburb_copy_paste_gauss.png"
img = skimage.io.imread(img_path)
patch_size = 7
iterations = 5
min_norm = 15
diff_threshold = 500.0

detector = CPD(img, patch_size, iterations, min_norm, diff_threshold, gaussian_filtering=True)
img = detector.img

# %% [markdown]
# ### Defining pairing parameters

# %%
cluster_eps=2.0
flat_threshold=0.05
min_cluster_size=300

# %% [markdown]
# ### Running copy-paste pairs detection

# %%
paired_result = detector.detect_paired_regions(cluster_eps, flat_threshold, min_cluster_size)
result = detection_results(img, paired_result)
display_results(img, result)

# %% [markdown]
# ## Sixth experiment

# %% [markdown]
# #### Defining PatchMatch parameteres and running algorithm

# %%
img_path = "../images/cercles_copy_paste_gauss.png"
img = skimage.io.imread(img_path)
patch_size = 7
iterations = 5
min_norm = 15
diff_threshold = 500.0

detector = CPD(img, patch_size, iterations, min_norm, diff_threshold, gaussian_filtering=True)
img = detector.img

# %% [markdown]
# ### Defining pairing parameters

# %%
cluster_eps=2.0
flat_threshold=0.05
min_cluster_size=300

# %% [markdown]
# ### Running copy-paste pairs detection

# %%
paired_result = detector.detect_paired_regions(cluster_eps, flat_threshold, min_cluster_size)
result = detection_results(img, paired_result)
display_results(img, result)

# %% [markdown]
# ## Seventh experiment

# %% [markdown]
# #### Defining PatchMatch parameteres and running algorithm

# %%
img_path = "../images/fleur_copy_paste_impulse1.png"
img = skimage.io.imread(img_path)
patch_size = 7
iterations = 5
min_norm = 15
diff_threshold = 500.0

detector = CPD(img, patch_size, iterations, min_norm, diff_threshold, median_filtering=True)
img = detector.img

# %% [markdown]
# ### Defining pairing parameters

# %%
cluster_eps=2.0
flat_threshold=0.05
min_cluster_size=300

# %% [markdown]
# ### Running copy-paste pairs detection

# %%
paired_result = detector.detect_paired_regions(cluster_eps, flat_threshold, min_cluster_size)
result = detection_results(img, paired_result)
display_results(img, result)

# %% [markdown]
# ## Eighth experiment

# %% [markdown]
# #### Defining PatchMatch parameteres and running algorithm

# %%
img_path = "../images/suburb_copy_paste_impulse1.png"
img = skimage.io.imread(img_path)
patch_size = 7
iterations = 5
min_norm = 15
diff_threshold = 500.0

detector = CPD(img, patch_size, iterations, min_norm, diff_threshold, median_filtering=True)
img = detector.img

# %% [markdown]
# ### Defining pairing parameters

# %%
cluster_eps=2.0
flat_threshold=0.05
min_cluster_size=300

# %% [markdown]
# ### Running copy-paste pairs detection

# %%
paired_result = detector.detect_paired_regions(cluster_eps, flat_threshold, min_cluster_size)
result = detection_results(img, paired_result)
display_results(img, result)

# %% [markdown]
# ## Ninth experiment

# %% [markdown]
# #### Defining PatchMatch parameteres and running algorithm

# %%
img_path = "../images/cercles_copy_paste_impulse1.png"
img = skimage.io.imread(img_path)
patch_size = 7
iterations = 5
min_norm = 15
diff_threshold = 500.0

detector = CPD(img, patch_size, iterations, min_norm, diff_threshold, median_filtering=True)
img = detector.img

# %% [markdown]
# ### Defining pairing parameters

# %%
cluster_eps=2.0
flat_threshold=0.05
min_cluster_size=300

# %% [markdown]
# ### Running copy-paste pairs detection

# %%
paired_result = detector.detect_paired_regions(cluster_eps, flat_threshold, min_cluster_size)
result = detection_results(img, paired_result)
display_results(img, result)

# %% [markdown]
# ## Tenth experiment

# %% [markdown]
# #### Defining PatchMatch parameteres and running algorithm

# %%
img_path = "../images/nature_inpainted_normal.png"
img = skimage.io.imread(img_path)
patch_size = 7
iterations = 5
min_norm = 15
diff_threshold = 500.0

detector = CPD(img, patch_size, iterations, min_norm, diff_threshold)
img = detector.img

# %% [markdown]
# ### Defining pairing parameters

# %%
cluster_eps=2.0
flat_threshold=0.05
min_cluster_size=300

# %% [markdown]
# ### Running copy-paste pairs detection

# %%
paired_result = detector.detect_paired_regions(cluster_eps, flat_threshold, min_cluster_size)
result = detection_results(img, paired_result)
display_results(img, result)

# %% [markdown]
# ## Eleventh experiment

# %% [markdown]
# #### Defining PatchMatch parameteres and running algorithm

# %%
img_path = "../images/lena_inpainted_4.png"
img = skimage.io.imread(img_path)
patch_size = 7
iterations = 5
min_norm = 15
diff_threshold = 500.0

detector = CPD(img, patch_size, iterations, min_norm, diff_threshold)
img = detector.img

# %% [markdown]
# ### Defining pairing parameters

# %%
cluster_eps=2.0
flat_threshold=0.05
min_cluster_size=300

# %% [markdown]
# ### Running copy-paste pairs detection

# %%
paired_result = detector.detect_paired_regions(cluster_eps, flat_threshold, min_cluster_size)
result = detection_results(img, paired_result)
display_results(img, result)

# %% [markdown]
# ## Twelfth experiment

# %% [markdown]
# #### Defining PatchMatch parameteres and running algorithm

# %%
img_path = "../images/nature_inpainted_gauss.png"
img = skimage.io.imread(img_path)
patch_size = 7
iterations = 5
min_norm = 15
diff_threshold = 500.0

detector = CPD(img, patch_size, iterations, min_norm, diff_threshold, gaussian_filtering=True)
img = detector.img

# %% [markdown]
# ### Defining pairing parameters

# %%
cluster_eps=2.0
flat_threshold=0.05
min_cluster_size=300

# %% [markdown]
# ### Running copy-paste pairs detection

# %%
paired_result = detector.detect_paired_regions(cluster_eps, flat_threshold, min_cluster_size)
result = detection_results(img, paired_result)
display_results(img, result)

# %% [markdown]
# ## Thirteenth experiment

# %% [markdown]
# #### Defining PatchMatch parameteres and running algorithm

# %%
img_path = "../images/lena_inpainted_4_gauss.png"
img = skimage.io.imread(img_path)
patch_size = 7
iterations = 5
min_norm = 15
diff_threshold = 500.0

detector = CPD(img, patch_size, iterations, min_norm, diff_threshold, gaussian_filtering=True)
img = detector.img

# %% [markdown]
# ### Defining pairing parameters

# %%
cluster_eps=2.0
flat_threshold=0.05
min_cluster_size=300

# %% [markdown]
# ### Running copy-paste pairs detection

# %%
paired_result = detector.detect_paired_regions(cluster_eps, flat_threshold, min_cluster_size)
result = detection_results(img, paired_result)
display_results(img, result)

# %% [markdown]
# ## Fourteenth experiment

# %% [markdown]
# #### Defining PatchMatch parameteres and running algorithm

# %%
img_path = "../images/nature_inpainted_normal_impulse1.png"
img = skimage.io.imread(img_path)
patch_size = 7
iterations = 5
min_norm = 15
diff_threshold = 500.0

detector = CPD(img, patch_size, iterations, min_norm, diff_threshold, median_filtering=True)
img = detector.img

# %% [markdown]
# ### Defining pairing parameters

# %%
cluster_eps=2.0
flat_threshold=0.05
min_cluster_size=300

# %% [markdown]
# ### Running copy-paste pairs detection

# %%
paired_result = detector.detect_paired_regions(cluster_eps, flat_threshold, min_cluster_size)
result = detection_results(img, paired_result)
display_results(img, result)

# %% [markdown]
# ## Fifteenth experiment

# %% [markdown]
# #### Defining PatchMatch parameteres and running algorithm

# %%
img_path = "../images/lena_inpainted_impulse1.png"
img = skimage.io.imread(img_path)
patch_size = 7
iterations = 5
min_norm = 15
diff_threshold = 500.0

detector = CPD(img, patch_size, iterations, min_norm, diff_threshold, median_filtering=True)
img = detector.img

# %% [markdown]
# ### Defining pairing parameters

# %%
cluster_eps=2.0
flat_threshold=0.05
min_cluster_size=300

# %% [markdown]
# ### Running copy-paste pairs detection

# %%
paired_result = detector.detect_paired_regions(cluster_eps, flat_threshold, min_cluster_size)
result = detection_results(img, paired_result)
display_results(img, result)
